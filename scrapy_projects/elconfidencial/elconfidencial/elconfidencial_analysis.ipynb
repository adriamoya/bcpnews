# %%
import os
import re
import json
import pprint
import datetime
import pandas as pd

#pp = pprint.PrettyPrinter(indent=4)

# %%
data = []
with open('/home/hm/Desktop/bluecap/bcpnews/newspaper_scraper/articles_elconfidencial.json') as input_file:
    for line in input_file:
        data.append(json.loads(line))

# %%
df = pd.DataFrame(data)
df.head(5)
# Out:
#                                              authors  \
# 0  [Marcos Lamelas. Barcelona, Antonio Fernández....
# 1                [Carlos Sánchez, Contacta Al Autor]
# 2  [Antonio Fernández. Sitges, José Antonio Zarza...
# 3  [Juanma Romero, Isabel Morillo. Sevilla, Conta...
# 4  [Juanma Romero, Víctor Romero. Valencia, Isabe...
#
#                                             keywords         publish_date  \
# 0  [el, por, se, que, como, generalitat, ultimar,...  2017-05-28 00:00:00
# 1  [nuestra, el, abusarás, que, la, se, hasta, lo...  2017-05-28 00:00:00
# 2  [el, rajoy, presidente, que, la, se, sea, cele...  2017-05-27 00:00:00
# 3  [el, se, su, plurinacional, estado, la, sánche...  2017-05-28 00:00:00
# 4  [el, por, su, se, la, que, sánchez, distancias...  2017-05-27 00:00:00
#
#                                              summary  \
# 0  La Generalitat está estudiando que el mes de a...
# 1  La conclusión a la que llegó fue que lo determ...
# 2  Lo hizo en el transcurso de su discurso de cla...
# 3  Pero Sánchez va mucho más allá: sostiene que e...
# 4  Pero entre los 69 compromisarios elegidos en C...
#
#                                                 text  \
# 0  La Generalitat está estudiando que el mes de a...
# 1  En la célebre conferencia que dictó Ernest Ren...
# 2  El presidente del Gobierno español, Mariano Ra...
# 3  La victoria no es todavía completa, aunque muy...
# 4  Ximo Puig no será el único presidente autonómi...
#
#                                                title  \
# 0  Vacaciones: La Generalitat estudia dejar a sus...
# 1  Geografía: ¿Hasta cuándo, Cataluña, abusarás d...
# 2  Independencia de Cataluña: Rajoy, en Barcelona...
# 3  Primarias PSOE: El PSOE de Sánchez: Estado plu...
# 4  Primarias PSOE: Page sigue a Puig y marca dist...
#
#                                            top_image  \
# 0  https://www.ecestaticos.com/imagestatic/clippi...
# 1  https://www.ecestaticos.com/imagestatic/clippi...
# 2  https://www.ecestaticos.com/imagestatic/clippi...
# 3  https://www.ecestaticos.com/imagestatic/clippi...
# 4  https://www.ecestaticos.com/imagestatic/clippi...
#
#                                                  url
# 0  https://www.elconfidencial.com/espana/cataluna...
# 1  https://blogs.elconfidencial.com/espana/mientr...
# 2  https://www.elconfidencial.com/espana/2017-05-...
# 3  https://www.elconfidencial.com/espana/2017-05-...
# 4  https://www.elconfidencial.com/espana/2017-05-...

# %%
"number of rows in jason file is " + str( df.shape[0] )
# Out:
# 'number of rows in jason file is 3214'

# %%
urls = df.url
urls.head(5)
# Out:
# 0    https://www.elconfidencial.com/espana/cataluna...
# 1    https://blogs.elconfidencial.com/espana/mientr...
# 2    https://www.elconfidencial.com/espana/2017-05-...
# 3    https://www.elconfidencial.com/espana/2017-05-...
# 4    https://www.elconfidencial.com/espana/2017-05-...
# Name: url, dtype: object

# %%
#  how manay unique article body text 
text = list(set(df.text))
len(text)
# Out:
# 3121

# %%
print("The number of rows in scrapy jason output file is", df.shape[0], ".")
print("However, only", len(text), "unique urls are in them.")
# Out:
# The number of rows in scrapy jason output file is 3214 .
# However, only 3121 unique urls are in them.

# %%
df.groupby('text').size().sort_values(0,ascending=False).reset_index().rename(columns={0:"count"}).head(10)
# Out:
#                                                 text  count
# 0  BIOGRAFÍA\n\nTrader, empezó su carrera profesi...     20
# 1                                                         4
# 2  Entrevista a Attila Szabo\n\n"Un 3% de los run...      4
# 3  5 de 15\n\nEn la imagen, Villa Sola, en Tremez...      2
# 4  Resido en el centro de Madrid y realizó con fr...      2
# 5  Me retiraron el carnet 8 meses por una condena...      2
# 6  Mi casera me sube el precio del alquiler 150 e...      2
# 7  Mi coche tiene tracción a las cuatro ruedas, e...      2
# 8  Dos homosexuales indonesios recibieron este ma...      2
# 9  Mi hijo está viviendo en Argentina desde hace ...      2

# %%
# Lets look at the text and url of the most frequent article text
idx = df.index[ df.text.str.contains('BIOGRAFÍA\n\nTrader, empezó su carrera')]
print(df.loc[idx[0]].url)
print(df.loc[idx[0]].text)
# Out:
# https://blogs.elconfidencial.com/mercados/bolsagora/2017-04-13/asi-cierra-mercado-bancos-mostrar-deterioro_1366748/
# BIOGRAFÍA
#
# Trader, empezó su carrera profesional en GVC en 1995. Es fundador de Ágora Asesores Financieros EAFI y uno de los analistas técnicos más reputados del panorama español. Ha colaborado con diversos medios de comunicación, entre los que se encuentra El Economista, desde su fundación hasta julio de 2014. Desde septiembre de 2014 se encarga de dirigir a la comunidad inversora de El Confidencial.

# %%
# remove all of the articles like above
df = df.drop(idx)

# %%
# Lets look at the text and url of the articles that repeated 4 times
idx = df.index[ df.text.str.contains('Entrevista a Attila Szabo\n\n"Un 3% de los')]
print(df.loc[idx[0]].url)
print(df.loc[idx[0]].text)
# Out:
# https://www.elconfidencial.com/alma-corazon-vida/running/2016-09-17/running-proyecto-documental-portada_1260314/
# Entrevista a Attila Szabo
#
# "Un 3% de los runners son adictos, del mismo modo que lo es un adicto al tabaco o a la heroína"

# %%
# again lets remove all of the articles like above because they are not really an article
df = df.drop(idx)

# %%
# remove all the articles without any text
df = df.drop( df[df['text']==''].index)

# %%
#removing the duplicate articles based on their text
df.drop_duplicates('text','first',True)
df.shape[0]
# Out:
# 3118

# %%
# extracting source column from the url of the articles
l = df['url'].apply(lambda x: re.findall('(?:\/\/\w+\.\w+\.\w+\/)(\w+)\/\w',x))
flat_list = []

for sublist in l:
    for item in sublist:
        flat_list.append(item)
df['source'] = pd.DataFrame(flat_list) 
df.head(5)
#print("\n".join(flat_list[0:10]))
# Out:
#                                              authors  \
# 0  [Marcos Lamelas. Barcelona, Antonio Fernández....
# 1                [Carlos Sánchez, Contacta Al Autor]
# 2  [Antonio Fernández. Sitges, José Antonio Zarza...
# 3  [Juanma Romero, Isabel Morillo. Sevilla, Conta...
# 4  [Juanma Romero, Víctor Romero. Valencia, Isabe...
#
#                                             keywords         publish_date  \
# 0  [el, por, se, que, como, generalitat, ultimar,...  2017-05-28 00:00:00
# 1  [nuestra, el, abusarás, que, la, se, hasta, lo...  2017-05-28 00:00:00
# 2  [el, rajoy, presidente, que, la, se, sea, cele...  2017-05-27 00:00:00
# 3  [el, se, su, plurinacional, estado, la, sánche...  2017-05-28 00:00:00
# 4  [el, por, su, se, la, que, sánchez, distancias...  2017-05-27 00:00:00
#
#                                              summary  \
# 0  La Generalitat está estudiando que el mes de a...
# 1  La conclusión a la que llegó fue que lo determ...
# 2  Lo hizo en el transcurso de su discurso de cla...
# 3  Pero Sánchez va mucho más allá: sostiene que e...
# 4  Pero entre los 69 compromisarios elegidos en C...
#
#                                                 text  \
# 0  La Generalitat está estudiando que el mes de a...
# 1  En la célebre conferencia que dictó Ernest Ren...
# 2  El presidente del Gobierno español, Mariano Ra...
# 3  La victoria no es todavía completa, aunque muy...
# 4  Ximo Puig no será el único presidente autonómi...
#
#                                                title  \
# 0  Vacaciones: La Generalitat estudia dejar a sus...
# 1  Geografía: ¿Hasta cuándo, Cataluña, abusarás d...
# 2  Independencia de Cataluña: Rajoy, en Barcelona...
# 3  Primarias PSOE: El PSOE de Sánchez: Estado plu...
# 4  Primarias PSOE: Page sigue a Puig y marca dist...
#
#                                            top_image  \
# 0  https://www.ecestaticos.com/imagestatic/clippi...
# 1  https://www.ecestaticos.com/imagestatic/clippi...
# 2  https://www.ecestaticos.com/imagestatic/clippi...
# 3  https://www.ecestaticos.com/imagestatic/clippi...
# 4  https://www.ecestaticos.com/imagestatic/clippi...
#
#                                                  url  source
# 0  https://www.elconfidencial.com/espana/cataluna...  espana
# 1  https://blogs.elconfidencial.com/espana/mientr...  espana
# 2  https://www.elconfidencial.com/espana/2017-05-...  espana
# 3  https://www.elconfidencial.com/espana/2017-05-...  espana
# 4  https://www.elconfidencial.com/espana/2017-05-...  espana

# %%
# extracting the section/source of the articles (useful for filtering unrelated sources)
df_source = df.groupby('source').size().sort_values(0, ascending=False).reset_index().rename(columns={0:"count"})
df_source.head(100)
# Out:
#           source  count
# 0         espana    623
# 1       deportes    315
# 2     multimedia    300
# 3       empresas    183
# 4        cultura    173
# 5     tecnologia    164
# 6          mundo    137
# 7       mercados    107
# 8       economia     90
# 9          motor     67
# 10  comunicacion     24
# 11      vivienda     23
# 12      sociedad     16
# 13       virales      4
# 14        viajes      4
# 15       product      1

# %%
#we can filter the unrelated sources like below. I didn't modified df here.
df_filtered = df[df.source.isin( df_source.source[:10] )]  
print("number of article left after filtering unrelated sources = ",df_filtered.shape[0])
# Out:
# number of article left after filtering unrelated sources =  2159

# %%
len( list(set(df_filtered.summary)) )
# Out:
# 2159

# %%
# 
df.groupby('publish_date').size().sort_values(0, ascending=False).reset_index().rename(columns={0:'count'}).head(10)
# Out:
#           publish_date  count
# 0  2018-04-05 00:00:00     69
# 1  2017-04-18 00:00:00     68
# 2  2017-04-26 00:00:00     67
# 3  2017-06-13 00:00:00     63
# 4  2017-09-25 00:00:00     63
# 5  2018-03-20 00:00:00     63
# 6  2017-10-19 00:00:00     62
# 7  2018-03-12 00:00:00     61
# 8  2018-01-23 00:00:00     60
# 9  2017-11-28 00:00:00     59

# %%
#split the publish date to date and time and remove time because it is not changing
df['date'], df['time'] = df.publish_date.str.split(' ').str#, columns = ['x' ,'y'])

df.drop(['time', 'publish_date'], axis = 1, inplace= True)
# Out:
#                                              authors  \
# 0  [Marcos Lamelas. Barcelona, Antonio Fernández....
# 1                [Carlos Sánchez, Contacta Al Autor]
# 2  [Antonio Fernández. Sitges, José Antonio Zarza...
# 3  [Juanma Romero, Isabel Morillo. Sevilla, Conta...
# 4  [Juanma Romero, Víctor Romero. Valencia, Isabe...
# 5                [Antonio Casado, Contacta Al Autor]
# 6                [Ignacio Varela, Contacta Al Autor]
# 7  [Ángel Collado, Juanma Romero, Contacta Al Autor]
# 8  [Beatriz Parera, Á. Collado, El Confidencial, ...
# 9  [Isabel Morillo. Sevilla, Juanma Romero, Conta...
#
#                                             keywords  \
# 0  [el, por, se, que, como, generalitat, ultimar,...
# 1  [nuestra, el, abusarás, que, la, se, hasta, lo...
# 2  [el, rajoy, presidente, que, la, se, sea, cele...
# 3  [el, se, su, plurinacional, estado, la, sánche...
# 4  [el, por, su, se, la, que, sánchez, distancias...
# 5  [el, se, que, la, moncloa, sánchez, lo, guardi...
# 6  [los, el, se, felipe, parece, que, iglesias, g...
# 7  [rajoy, el, presupuestos, pese, que, la, se, e...
# 8  [el, tren, su, que, la, gonzález, lezo, en, se...
# 9  [los, el, por, natural, su, díaz, la, que, tom...
#
#                                              summary  \
# 0  La Generalitat está estudiando que el mes de a...
# 1  La conclusión a la que llegó fue que lo determ...
# 2  Lo hizo en el transcurso de su discurso de cla...
# 3  Pero Sánchez va mucho más allá: sostiene que e...
# 4  Pero entre los 69 compromisarios elegidos en C...
# 5  Y ahora el PSOE de Pedro Sánchez, como el de F...
# 6  Un acontecimiento como la primera moción de ce...
# 7  El PSOE, sin Sánchez, no se abstuvo entonces: ...
# 8  El cerebro del Canal alertó a González de que ...
# 9  Susana Díaz estará este miércoles, como el res...
#
#                                                 text  \
# 0  La Generalitat está estudiando que el mes de a...
# 1  En la célebre conferencia que dictó Ernest Ren...
# 2  El presidente del Gobierno español, Mariano Ra...
# 3  La victoria no es todavía completa, aunque muy...
# 4  Ximo Puig no será el único presidente autonómi...
# 5  Me lo dicen y me lo cuentan. Que esta oleada d...
# 6  Pablo Iglesias ha evocado repetidamente la moc...
# 7  Pedro Sánchez ha logrado volver a la Secretarí...
# 8  Edmundo Rodríguez Sobrino, cerebro del Canal d...
# 9  Susana Díaz estará este miércoles, como el res...
#
#                                                title  \
# 0  Vacaciones: La Generalitat estudia dejar a sus...
# 1  Geografía: ¿Hasta cuándo, Cataluña, abusarás d...
# 2  Independencia de Cataluña: Rajoy, en Barcelona...
# 3  Primarias PSOE: El PSOE de Sánchez: Estado plu...
# 4  Primarias PSOE: Page sigue a Puig y marca dist...
# 5  Sánchez se pone en guardia ante Moncloa y Podemos
# 6  Moción de censura: ¿Se parece la moción de cen...
# 7  Presupuestos Generales del Estado: Rajoy negoc...
# 8  Caso Lezo: El cerebro del Canal alertó a Gonzá...
# 9  Primarias PSOE: Díaz toma Barcelona junto a Ic...
#
#                                            top_image  \
# 0  https://www.ecestaticos.com/imagestatic/clippi...
# 1  https://www.ecestaticos.com/imagestatic/clippi...
# 2  https://www.ecestaticos.com/imagestatic/clippi...
# 3  https://www.ecestaticos.com/imagestatic/clippi...
# 4  https://www.ecestaticos.com/imagestatic/clippi...
# 5  https://www.ecestaticos.com/imagestatic/clippi...
# 6  https://www.ecestaticos.com/imagestatic/clippi...
# 7  https://www.ecestaticos.com/imagestatic/clippi...
# 8  https://www.ecestaticos.com/imagestatic/clippi...
# 9  https://www.ecestaticos.com/imagestatic/clippi...
#
#                                                  url  source           A  \
# 0  https://www.elconfidencial.com/espana/cataluna...  espana  2017-05-28
# 1  https://blogs.elconfidencial.com/espana/mientr...  espana  2017-05-28
# 2  https://www.elconfidencial.com/espana/2017-05-...  espana  2017-05-27
# 3  https://www.elconfidencial.com/espana/2017-05-...  espana  2017-05-28
# 4  https://www.elconfidencial.com/espana/2017-05-...  espana  2017-05-27
# 5  https://blogs.elconfidencial.com/espana/al-gra...  espana  2017-05-27
# 6  https://blogs.elconfidencial.com/espana/una-ci...  espana  2017-05-28
# 7  https://www.elconfidencial.com/espana/2017-05-...  espana  2017-05-28
# 8  https://www.elconfidencial.com/espana/2017-04-...  espana  2017-04-26
# 9  https://www.elconfidencial.com/espana/andaluci...  espana  2017-04-18
#
#           B        date
# 0  00:00:00  2017-05-28
# 1  00:00:00  2017-05-28
# 2  00:00:00  2017-05-27
# 3  00:00:00  2017-05-28
# 4  00:00:00  2017-05-27
# 5  00:00:00  2017-05-27
# 6  00:00:00  2017-05-28
# 7  00:00:00  2017-05-28
# 8  00:00:00  2017-04-26
# 9  00:00:00  2017-04-18

# %%
#convert date columns to datetime and create day_of_week column

df['date'] = pd.to_datetime(df['date'])
df['day_of_week'] = df['date'].dt.weekday_name
df.head()
# Out:
#                                              authors  \
# 0  [Marcos Lamelas. Barcelona, Antonio Fernández....
# 1                [Carlos Sánchez, Contacta Al Autor]
# 2  [Antonio Fernández. Sitges, José Antonio Zarza...
# 3  [Juanma Romero, Isabel Morillo. Sevilla, Conta...
# 4  [Juanma Romero, Víctor Romero. Valencia, Isabe...
#
#                                             keywords  \
# 0  [el, por, se, que, como, generalitat, ultimar,...
# 1  [nuestra, el, abusarás, que, la, se, hasta, lo...
# 2  [el, rajoy, presidente, que, la, se, sea, cele...
# 3  [el, se, su, plurinacional, estado, la, sánche...
# 4  [el, por, su, se, la, que, sánchez, distancias...
#
#                                              summary  \
# 0  La Generalitat está estudiando que el mes de a...
# 1  La conclusión a la que llegó fue que lo determ...
# 2  Lo hizo en el transcurso de su discurso de cla...
# 3  Pero Sánchez va mucho más allá: sostiene que e...
# 4  Pero entre los 69 compromisarios elegidos en C...
#
#                                                 text  \
# 0  La Generalitat está estudiando que el mes de a...
# 1  En la célebre conferencia que dictó Ernest Ren...
# 2  El presidente del Gobierno español, Mariano Ra...
# 3  La victoria no es todavía completa, aunque muy...
# 4  Ximo Puig no será el único presidente autonómi...
#
#                                                title  \
# 0  Vacaciones: La Generalitat estudia dejar a sus...
# 1  Geografía: ¿Hasta cuándo, Cataluña, abusarás d...
# 2  Independencia de Cataluña: Rajoy, en Barcelona...
# 3  Primarias PSOE: El PSOE de Sánchez: Estado plu...
# 4  Primarias PSOE: Page sigue a Puig y marca dist...
#
#                                            top_image  \
# 0  https://www.ecestaticos.com/imagestatic/clippi...
# 1  https://www.ecestaticos.com/imagestatic/clippi...
# 2  https://www.ecestaticos.com/imagestatic/clippi...
# 3  https://www.ecestaticos.com/imagestatic/clippi...
# 4  https://www.ecestaticos.com/imagestatic/clippi...
#
#                                                  url  source           A  \
# 0  https://www.elconfidencial.com/espana/cataluna...  espana  2017-05-28
# 1  https://blogs.elconfidencial.com/espana/mientr...  espana  2017-05-28
# 2  https://www.elconfidencial.com/espana/2017-05-...  espana  2017-05-27
# 3  https://www.elconfidencial.com/espana/2017-05-...  espana  2017-05-28
# 4  https://www.elconfidencial.com/espana/2017-05-...  espana  2017-05-27
#
#           B       date day_of_week
# 0  00:00:00 2017-05-28      Sunday
# 1  00:00:00 2017-05-28      Sunday
# 2  00:00:00 2017-05-27    Saturday
# 3  00:00:00 2017-05-28      Sunday
# 4  00:00:00 2017-05-27    Saturday

# %%
#number of articles in different days of the week
df.groupby('day_of_week').size().sort_values(0, ascending=False).reset_index().rename(columns={0:'count'}).head(10)
# Out:
#   day_of_week  count
# 0     Tuesday    553
# 1   Wednesday    523
# 2    Thursday    483
# 3      Monday    448
# 4    Saturday    397
# 5      Friday    382
# 6      Sunday    330
