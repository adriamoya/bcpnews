# %% [markdown]
# # Articles for training  - Emails (target)
#
# Checking the newspaper output for all urls downloaded from all emails sent.
#
# * There are __4.209__ articles downloaded from all emails urls.
# * There are __70__ articles without text.
# * There are __39__ articles with useless text.
#
# Therefore there are roughly __4.100__ target articles that can be currently considered.

# %%
import os
import re
import json
import pprint
import datetime
import pandas as pd

pp = pprint.PrettyPrinter(indent=4)

# %%
data = []
with open('./articles_email.json') as input_file:
    for line in input_file:
        data.append(json.loads(line))
        
raw_emails = []
with open('../mail_download/emails.json') as input_file:
    for line in input_file:
        raw_emails.append(json.loads(line))

# %%
urls = []
for item in raw_emails:
    try:
        for url in item['urls']:
            urls.append(url)
    except:
        pass

# %%
# Delete possible dups
urls = list(set(urls))
len(urls)
# Out:
# 4313

# %%
df = pd.DataFrame(data)

print("There were", len(urls), "urls extracted from all emails.")
print("However, only", df.shape[0], "urls correctly yield to articles.")
# Out:
# There were 4313 urls extracted from all emails.
# However, only 4209 urls correctly yield to articles.

# %%
df.head(5)
# Out:
#   authors                                           keywords  \
# 0      []  [yetthe, website, services, login, custom, rep...
# 1      []  [yetthe, website, services, login, custom, rep...
# 2      []  [yetthe, website, services, login, custom, rep...
# 3      []  [situación, en, bancos, que, por, los, la, se,...
# 4      []  [search, scheduled, meeting, regularly, fomc, ...
#
#                 publish_date  \
# 0                       None
# 1                       None
# 2                       None
# 3  2016-03-01 21:27:34+00:00
# 4                       None
#
#                                              summary  \
# 0  Don't have an account yet?\nThe content of thi...
# 1  Don't have an account yet?\nThe content of thi...
# 2  Don't have an account yet?\nThe content of thi...
# 3  Primero la situación económica de China, despu...
# 4  Meeting calendars, statements, and minutes (20...
#
#                                                 text  \
# 0  Don't have an account yet?\n\nThe content of t...
# 1  Don't have an account yet?\n\nThe content of t...
# 2  Don't have an account yet?\n\nThe content of t...
# 3  Desde que empezó el año hemos tenido ya 3 fact...
# 4  Meeting calendars, statements, and minutes (20...
#
#                                    title  \
# 0                         » custom login
# 1                         » custom login
# 2                         » custom login
# 3  Nota sobre la situación de los bancos
# 4      Meeting calendars and information
#
#                                            top_image  \
# 0  https://www.bbvagmr.com/wp-content/themes/bbva...
# 1  https://www.bbvagmr.com/wp-content/themes/bbva...
# 2  https://www.bbvagmr.com/wp-content/themes/bbva...
# 3  http://www.robust.fondos.gvcgaesco.es/wp-conte...
# 4
#
#                                                  url
# 0  http://www.bbvagmr.com/wp-content/plugins/misc...
# 1  http://www.bbvagmr.com/wp-content/plugins/misc...
# 2  http://www.bbvagmr.com/wp-content/plugins/misc...
# 3  http://www.robustglobal.com/nota-sobre-la-situ...
# 4  http://www.federalreserve.gov/monetarypolicy/f...

# %%
# Data Wrangling

keywords = []

df['source'] = df['url'].apply(lambda x: re.findall('(?:\/\/www\.|\/\/)(\w+)\.\w',x))

for idx, row in df.iterrows():
    authors = ' / '.join(row['authors'])
    df.loc[idx, 'authors'] = authors
    
    for keyw in row['keywords']:
        keywords.append(keyw)
        
    source = row['source']
    try:
        df.loc[idx, 'source'] = source[0]
    except:
        df.loc[idx, 'source'] = ""

# %%
df.head(5)
# Out:
#   authors                                           keywords  \
# 0          [password, investment, yetthe, username, websi...
# 1          [password, investment, yetthe, username, websi...
# 2          [password, investment, yetthe, username, websi...
# 3          [se, por, la, el, y, los, las, nota, sobre, de...
# 4          [statements, minutes, meetings, calendars, foi...
#
#                 publish_date  \
# 0                       None
# 1                       None
# 2                       None
# 3  2016-03-01 21:27:34+00:00
# 4                       None
#
#                                              summary  \
# 0  Don't have an account yet?\nThe content of thi...
# 1  Don't have an account yet?\nThe content of thi...
# 2  Don't have an account yet?\nThe content of thi...
# 3  Primero la situación económica de China, despu...
# 4  Meeting calendars, statements, and minutes (20...
#
#                                                 text  \
# 0  Don't have an account yet?\n\nThe content of t...
# 1  Don't have an account yet?\n\nThe content of t...
# 2  Don't have an account yet?\n\nThe content of t...
# 3  Desde que empezó el año hemos tenido ya 3 fact...
# 4  Meeting calendars, statements, and minutes (20...
#
#                                    title  \
# 0                         » custom login
# 1                         » custom login
# 2                         » custom login
# 3  Nota sobre la situación de los bancos
# 4      Meeting calendars and information
#
#                                            top_image  \
# 0  https://www.bbvagmr.com/wp-content/themes/bbva...
# 1  https://www.bbvagmr.com/wp-content/themes/bbva...
# 2  https://www.bbvagmr.com/wp-content/themes/bbva...
# 3  http://www.robust.fondos.gvcgaesco.es/wp-conte...
# 4
#
#                                                  url          source
# 0  http://www.bbvagmr.com/wp-content/plugins/misc...         bbvagmr
# 1  http://www.bbvagmr.com/wp-content/plugins/misc...         bbvagmr
# 2  http://www.bbvagmr.com/wp-content/plugins/misc...         bbvagmr
# 3  http://www.robustglobal.com/nota-sobre-la-situ...    robustglobal
# 4  http://www.federalreserve.gov/monetarypolicy/f...  federalreserve

# %% [markdown]
# ### Source

# %%
df_source = df.groupby('source').size().sort_values(0, ascending=False).reset_index().rename(columns={0:"count"})
df_source.head(10)
# Out:
#               source  count
# 0          expansion   2182
# 1          cincodias   1100
# 2     elconfidencial    728
# 3  bernsteinresearch     73
# 4              blogs     31
# 5     federalreserve     13
# 6             retina     12
# 7           economia      6
# 8            bbvagmr      4
# 9          bloomberg      4

# %% [markdown]
# ### Authors

# %%
df.groupby(['authors']).size().sort_values(0, ascending=False).reset_index().rename(columns={0: "count"}).head(15)
# Out:
#                                               authors  count
# 0                                                       2351
# 1                            Ángeles Gonzalo Alconada    162
# 2                                          Cinco Días    104
# 3                                     Juande Portillo     65
# 4              Ángeles Gonzalo Alconada / Pablo Monge     34
# 5                 Eduardo Segovia / Contacta Al Autor     31
# 6                                      Nuria Salobral     25
# 7                       Juande Portillo / Pablo Monge     22
# 8                                  Pablo Martín Simón     21
# 9                                  Bernardo De Miguel     18
# 10                             Miguel Moreno Mendieta     16
# 11                               Ediciones Cinco Días     15
# 12  Agustín Marco / Eduardo Segovia / Contacta Al ...     15
# 13                           Cinco Días / Pablo Monge     13
# 14                    Ruth Ugalde / Contacta Al Autor     12

# %% [markdown]
# ### Text

# %%
# articles without text (#70)

df[df['text']=='']['text'].count()
# Out:
# 70

# %%
df[df['text']==''].groupby('source').size().sort_values(0, ascending=False).reset_index().rename(columns={0:"count"})
# Out:
#                 source  count
# 0    bernsteinresearch     38
# 1       elconfidencial     13
# 2                  imf      3
# 3         lavanguardia      2
# 4       federalreserve      2
# 5                blogs      2
# 6         bbvaresearch      2
# 7               prensa      1
# 8           nobelprize      1
# 9            idealista      1
# 10               hugin      1
# 11   grupobancopopular      1
# 12           economist      1
# 13                cnmv      1
# 14  bankingsupervision      1

# %%
# those without title do not have text either (#13, already included in query above)

df[df['title']==""]
# Out:
#      authors keywords publish_date summary text title top_image  \
# 250                []         None
# 251                []         None
# 330                []         None
# 426                []         None
# 737                []         None
# 829                []         None
# 841                []         None
# 853                []         None
# 866                []         None
# 869                []         None
# 925                []         None
# 3136               []         None
# 4040               []         None
#
#                                                     url              source
# 250   https://www.bbvaresearch.com/wp-content/upload...        bbvaresearch
# 251   https://www.bbvaresearch.com/wp-content/upload...        bbvaresearch
# 330   http://cnmv.es/portal/HR/verDoc.axd?t=3D%7bee5...                cnmv
# 426   https://www.federalreserve.gov/monetarypolicy/...      federalreserve
# 737       http://hugin.info/134323/R/2043980/763188.pdf               hugin
# 829   http://www.grupobancopopular.com/ES/Accionista...   grupobancopopular
# 841   http://www.imf.org/external/pubs/ft/weo/2016/0...                 imf
# 853   http://www.imf.org/external/pubs/ft/weo/2016/0...                 imf
# 866   https://www.nobelprize.org/nobel_prizes/econom...          nobelprize
# 869   http://www.imf.org/external/pubs/ft/weo/2016/0...                 imf
# 925   http://www.federalreserve.gov/monetarypolicy/b...      federalreserve
# 3136  https://www.bankingsupervision.europa.eu/legal...  bankingsupervision
# 4040  https://www.economist.com/news/britain/2173890...           economist

# %%
df.groupby('text').size().sort_values(0,ascending=False).reset_index().rename(columns={0:"count"}).head(10)
# Out:
#                                                 text  count
# 0                                                        70
# 1  How Can We Help?\n\nIf you'd like to learn mor...     35
# 2  Estas personas se consideran víctimas y no cóm...      5
# 3  Don't have an account yet?\n\nThe content of t...      4
# 4  Sucesión de mentirijillas en BBVA: Francisco G...      4
# 5  Consulte las citas más relevantes de la jornad...      4
# 6  El ministro de Economía aseguró que la resoluc...      3
# 7  Danièle Nouy, presidenta del Supervisor Único,...      3
# 8  El Royal Bank of Scotland (RBS) pagará 500 mil...      2
# 9  La tecnología blockchain se está convirtiendo ...      2

# %%
idx = df[df['text'].str.contains('How Can We Help')].index[0]
print("\nBernsteinresearch text:\n\n", df.loc[idx]['text'], "\n")
# Out:
# Bernsteinresearch text:
#
#  How Can We Help?
#
# If you'd like to learn more about Bernstein's insights and execution or how they can help advance your business, please contact us.

# %%
# a few bernsteinresearch articles cannot be scraped (#35)

df[df['text'].str.contains('How Can We Help')].groupby('source').size().sort_values(0,ascending=False).reset_index().rename(columns={0:"count"})
# Out:
#               source  count
# 0  bernsteinresearch     35

# %%
idx = df[df['title'].str.contains('custom login')].index[0]
print("\nbbvagmr text:\n\n", df.loc[idx]['text'], "\n")
# Out:
# bbvagmr text:
#
#  Don't have an account yet?
#
# The content of this website is for the exclusive access of BBVA Corporate & Investment Banking authorized clients.
#
# If you need a username and password or require further information about our services, please contact your Corporate & Investment Banking representative. Alternatively, please use the link below:
#
# Contact us now

# %%
# bbvagmr cannot be scraped since it requests login credentials (#4)

df[df['title'].str.contains('custom login')]
# Out:
#     authors                                           keywords publish_date  \
# 0            [password, investment, yetthe, username, websi...         None
# 1            [password, investment, yetthe, username, websi...         None
# 2            [password, investment, yetthe, username, websi...         None
# 107          [password, investment, yetthe, username, websi...         None
#
#                                                summary  \
# 0    Don't have an account yet?\nThe content of thi...
# 1    Don't have an account yet?\nThe content of thi...
# 2    Don't have an account yet?\nThe content of thi...
# 107  Don't have an account yet?\nThe content of thi...
#
#                                                   text           title  \
# 0    Don't have an account yet?\n\nThe content of t...  » custom login
# 1    Don't have an account yet?\n\nThe content of t...  » custom login
# 2    Don't have an account yet?\n\nThe content of t...  » custom login
# 107  Don't have an account yet?\n\nThe content of t...  » custom login
#
#                                              top_image  \
# 0    https://www.bbvagmr.com/wp-content/themes/bbva...
# 1    https://www.bbvagmr.com/wp-content/themes/bbva...
# 2    https://www.bbvagmr.com/wp-content/themes/bbva...
# 107  https://www.bbvagmr.com/wp-content/themes/bbva...
#
#                                                    url   source
# 0    http://www.bbvagmr.com/wp-content/plugins/misc...  bbvagmr
# 1    http://www.bbvagmr.com/wp-content/plugins/misc...  bbvagmr
# 2    http://www.bbvagmr.com/wp-content/plugins/misc...  bbvagmr
# 107  http://www.bbvagmr.com/wp-content/plugins/misc...  bbvagmr

# %% [markdown]
# ---
#
# # Articles for training - Historical data
#
# Checking the newspaper output for all urls scraped from the different source to build the training dataset.
#
# __Considerations__
#
# * Articles with __no text__.
# * Note that some of these __articles may be included in the emails__ sent over these years.
# * Currenty working with articles __published on mondays__ regardless of the source.
# * Handle errors/exceptions in the download method of the newspaper.
#
# ---

# %% [markdown]
# ## Expansion
#
# * Run every Monday between 2017/04/10 and 2018/04/10 (5.871 urls)
# * There are #32 urls without text (5.839 useful articles)
# * It might be necessary to focus on determinate sections or type of articles and clean the database (and perhaps increase the frequency of the scrapy process to download more articles)

# %%
# raw urls extracted with Scrapy
urls = []
with open('../scrapy_projects/expansion_hemeroteca/urls_expansion.json') as input_file:
    for line in input_file:
        urls.append(json.loads(line))

# article content downloaded and parsed with newspaper3k
data = []
with open('./articles_expansion_hemeroteca.json') as input_file:
    for line in input_file:
        data.append(json.loads(line))

# %%
print "# of raw urls scraped from Expansion:", len(urls)
# Out:
# # of raw urls scraped from Expansion: 5871

# %%
df = pd.DataFrame(data)

# %%
df.shape
# Out:
# (5871, 8)

# %%
df.head(2)
# Out:
#   authors                                           keywords  \
# 0      []  [dato, el, resumen, completar, declaraciones, ...
# 1      []  [decisiones, el, recursos, personas, talento, ...
#
#           publish_date                                            summary  \
# 0  2017-05-15 00:00:00  Renta 2016: Cómo completar un dato ya incluido...
# 1  2017-05-15 00:00:00  El cambio tecnológico provoca una gran transfo...
#
#                                                 text  \
# 0  Renta 2016: Cómo completar un dato ya incluido...
# 1  El cambio tecnológico provoca una gran transfo...
#
#                                                title  \
# 0  Renta 2016: Cómo completar un dato ya incluido...
# 1  Valores y personas se colocan en el foco de la...
#
#                                            top_image  \
# 0  http://v.uecdn.es/p/111/thumbnail/entry_id/0_y...
# 1  http://estaticos.expansion.com/assets/multimed...
#
#                                                  url
# 0  http://www.expansion.com/economia/declaracion-...
# 1  http://www.expansion.com/pais-vasco/2017/05/15...

# %%
# create seccion field from url
df['seccion'] = df['url'].apply(lambda x: x.split('/')[3])

# %%
df.groupby('seccion').size().sort_values(0, ascending=False).reset_index().rename(columns={0:'count'})
# Out:
#                  seccion  count
# 0               empresas   1249
# 1               economia   1039
# 2                 aragon    546
# 3               mercados    516
# 4            extremadura    439
# 5           fueradeserie    407
# 6               juridico    233
# 7               sociedad    220
# 8             directivos    188
# 9          latinoamerica    173
# 10      economia-digital    155
# 11              valencia    144
# 12             catalunya    108
# 13              nauta360    102
# 14                 pymes     60
# 15  emprendedores-empleo     56
# 16   actualidadeconomica     47
# 17             andalucia     41
# 18            pais-vasco     39
# 19               opinion     35
# 20            tecnologia     32
# 21      expansion-empleo     24
# 22                ahorro      9
# 23               portada      6
# 24            especiales      3

# %%
df.groupby('publish_date').size().reset_index().rename(columns={0:'count'}).head(10)
# Out:
#           publish_date  count
# 0  2017-04-10 00:00:00    141
# 1  2017-04-17 00:00:00     92
# 2  2017-04-24 00:00:00    144
# 3  2017-05-01 00:00:00     39
# 4  2017-05-08 00:00:00    120
# 5  2017-05-15 00:00:00     55
# 6  2017-05-22 00:00:00    147
# 7  2017-05-29 00:00:00    115
# 8  2017-06-05 00:00:00    132
# 9  2017-06-12 00:00:00    109

# %%
# articles without text (#32)

df[df['text']=='']['text'].count()
# Out:
# 32

# %%
# articles without title (#2, one of the does not have text)

df[df['title']=='']
# Out:
#      authors                                           keywords  \
# 714       []  [está, esta, ella, y, se, puede, cerrada, vota...
# 5788      []                                                 []
#
#              publish_date summary  \
# 714   2017-05-22 00:00:00
# 5788  2018-02-19 00:00:00
#
#                                                    text title  \
# 714   Esta encuesta está cerrada y no se puede votar...
# 5788
#
#                                               top_image  \
# 714   http://estaticos.expansion.com/assets/desktop/...
# 5788
#
#                                                     url   seccion
# 714   http://www.expansion.com/economia/politica/deb...  economia
# 5788  http://www.expansion.com/juridico/premios/2018...  juridico

# %% [markdown]
# ---
#
# ## Cincodias
#
# * Run every two weeks on mondays between 2017/04/10 and 2018/04/10 (1.390 urls)
# * There are #0 urls without text (1.390 useful articles)
# * It might be necessary to focus on determinate sections or type of articles and clean the database (and perhaps increase the frequency of the scrapy process to download more articles)

# %%
# raw urls extracted with Scrapy
urls = []
with open('../scrapy_projects/cincodias/urls_cincodias.json') as input_file:
    for line in input_file:
        urls.append(json.loads(line))
        
# article content downloaded and parsed with newspaper3k
data = []        
with open('./articles_cincodias.json') as input_file:
    for line in input_file:
        data.append(json.loads(line))

# %%
print "# of raw urls scraped from Cincodias:", len(urls)
# Out:
# # of raw urls scraped from Cincodias: 1390

# %%
df = pd.DataFrame(data)
df.shape
# Out:
# (1390, 8)

# %%
df.head(5)
# Out:
#                                     authors  \
# 0                         [Marimar Jiménez]
# 1                    [Ediciones Cinco Días]
# 2  [Pablo Martín Simón, Alfonso Simón Ruiz]
# 3        [Javier García Ropero, Mike Segar]
# 4                           [Carlos Molina]
#
#                                             keywords         publish_date  \
# 0  [en, tercio, millones, por, ventas, el, las, i...  2017-04-10 00:00:00
# 1  [partners, en, ritzcarlton, del, abama, el, hi...  2017-04-10 00:00:00
# 2  [aprueba, en, del, el, ofrece, la, como, inmob...  2017-05-08 00:00:00
# 3  [niño, sergio, al, en, del, el, dar, garcía, l...  2017-04-10 00:00:00
# 4  [frente, barata, en, al, ciudad, ir, el, barce...  2017-04-10 00:00:00
#
#                                              summary  \
# 0  La industria del videojuego continúa creciendo...
# 1  Tropical Hoteles, propiedad del Grupo Timón, a...
# 2  Es la mayor plataforma del sector, con más de ...
# 3  En abril de 1999, un joven de 19 años de Borri...
# 4  Desplazarse desde el centro de la ciudad hasta...
#
#                                                 text  \
# 0  La industria del videojuego continúa creciendo...
# 1  Tropical Hoteles, propiedad del Grupo Timón, a...
# 2  Housers se presenta como "la plataforma líder ...
# 3  En abril de 1999, un joven de 19 años de Borri...
# 4  Desplazarse desde el centro de la ciudad hasta...
#
#                                                title  \
# 0  Un tercio de las ventas de videojuegos en Espa...
# 1  Tropical Hoteles vende a HI Partners el 49,9% ...
# 2  La CNMV aprueba a Housers como plataforma inmo...
# 3  Sergio García, 'El Niño' que vuelve a dar aire...
# 4  Barcelona, la ciudad más barata para ir en tax...
#
#                                            top_image  \
# 0  https://d500.epimg.net/cincodias/imagenes/2017...
# 1  https://d500.epimg.net/cincodias/imagenes/2017...
# 2  https://d500.epimg.net/cincodias/imagenes/2017...
# 3  https://d500.epimg.net/cincodias/imagenes/2017...
# 4  https://d500.epimg.net/cincodias/imagenes/2017...
#
#                                                  url
# 0  https://cincodias.elpais.com/cincodias/2017/04...
# 1  https://cincodias.elpais.com/cincodias/2017/04...
# 2  https://cincodias.elpais.com/cincodias/2017/05...
# 3  https://cincodias.elpais.com/cincodias/2017/04...
# 4  https://cincodias.elpais.com/cincodias/2017/04...

# %%
# articles without text (#0)

df[df['text']=='']['text'].count()
# Out:
# 0

# %% [markdown]
# ---
#
# ## El Confidencial
#
# * Run every two weeks on mondays between 2017/04/10 and 2018/04/10 (1.800 urls)
# * There are #2 urls without text and #4 articles that could not be downloaded (1.794 useful articles)
# * It might be necessary to focus on determinate sections or type of articles and clean the database (and perhaps increase the frequency of the scrapy process to download more articles)

# %%
# raw urls extracted with Scrapy
urls = []
with open('../scrapy_projects/elconfidencial/urls_elconfidencial.json') as input_file:
    for line in input_file:
        urls.append(json.loads(line))

# article content downloaded and parsed with newspaper3k
data = []
with open('./articles_elconfidencial.json') as input_file:
    for line in input_file:
        data.append(json.loads(line))

# %%
print "# of raw urls scraped from El Confidencial:", len(urls)
# Out:
# # of raw urls scraped from El Confidencial: 1800

# %%
df = pd.DataFrame(data)
df.shape
# Out:
# (1796, 8)

# %%
df.head(5)
# Out:
#                                              authors  \
# 0  [Rafael, Fotografía, Enrique Villarino, Eduard...
# 1  [Eduardo Segovia, Agustín Marco, E. Segovia, C...
# 2  [Isabel Morillo, Juanma Romero, Contacta Al Au...
# 3  [Isabel Morillo, Juanma Romero, Contacta Al Au...
# 4  [Juanma Romero, Isabel Morillo, Contacta Al Au...
#
#                                             keywords         publish_date  \
# 0  [la, en, noticias, supremo, el, que, una, paga...  2017-06-19 00:00:00
# 1  [del, vender, el, reprocha, que, una, se, plan...  2017-06-05 00:00:00
# 2  [del, el, que, segunda, va, sánchez, su, por, ...  2017-06-19 00:00:00
# 3  [las, del, federal, reabre, el, que, se, más, ...  2017-06-18 00:00:00
# 4  [pronto, del, las, mandato, el, que, una, misi...  2017-06-19 00:00:00
#
#                                              summary  \
# 0  Sostienen que el mismo dinero que les sirvió p...
# 1  Uno de sus componentes, molesto con la actual ...
# 2  El día después de la batalla no habrá tregua e...
# 3  Fue la última en entrevistarse con Pedro Sánch...
# 4  Que hiciera el equipo que quisiera, que sacara...
#
#                                                 text  \
# 0  Jaime Botín, patrón de Bankinter y procesado p...
# 1  "Enfado monumental". Así califican varios miem...
# 2  El día después de la batalla no habrá tregua e...
# 3  La jornada acabó mal. Pasadas las once de la n...
# 4  El reinado de Pedro Sánchez ya ha comenzado. E...
#
#                                                title  \
# 0  Lista Falciani: Jaime Botín e hijos reclaman e...
# 1  Noticias del Banco Popular: El consejo del Ban...
# 2  39° Congreso Federal del PSOE: El PSOE afronta...
# 3  39° Congreso Federal del PSOE: El pulso de Ped...
# 4  39° Congreso Federal del PSOE: Sánchez arranca...
#
#                                            top_image  \
# 0  https://www.ecestaticos.com/imagestatic/clippi...
# 1  https://www.ecestaticos.com/imagestatic/clippi...
# 2  https://www.ecestaticos.com/imagestatic/clippi...
# 3  https://www.ecestaticos.com/imagestatic/clippi...
# 4  https://www.ecestaticos.com/imagestatic/clippi...
#
#                                                  url
# 0  https://www.elconfidencial.com/empresas/2017-0...
# 1  https://www.elconfidencial.com/empresas/2017-0...
# 2  https://www.elconfidencial.com/espana/2017-06-...
# 3  https://www.elconfidencial.com/espana/2017-06-...
# 4  https://www.elconfidencial.com/espana/2017-06-...

# %%
# articles without text (#2)

df[df['text']=='']['text'].count()
# Out:
# 2
